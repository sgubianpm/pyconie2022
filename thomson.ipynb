# %%
import matplotlib
matplotlib.use('QtAgg')
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import animation
import numpy as np
from scipy.optimize import dual_annealing

def polar_to_cartesian(m):
    return np.array([
        np.sin(m[0]) * np.cos(m[1]),
        np.sin(m[0]) * np.sin(m[1]),
        np.cos(m[0])
    ])

def filter_indexes(x):
    return np.any(x[0] < x[1])


class Thomson(object):
    def __init__(self) -> None:
        self.nb_call = 0
        self.best_value = np.inf

    def objective(self, x):
        x_mat = np.array(x).reshape(len(x) // 2, 2, order='F')

        
        def rdist_fun(x):
            return np.array(
                1 / np.sqrt(np.sum(
                    (y_mat[x[0]] - y_mat[x[1]])** 2))
            )

        y_mat = np.apply_along_axis(polar_to_cartesian, axis=1, arr=x_mat)
        seq_vec = np.arange(0, x_mat.shape[0])
        indexes = np.array(np.meshgrid(seq_vec, seq_vec)).T.reshape(-1, 2)
        filter_vec = np.apply_along_axis(filter_indexes, axis=1, arr=indexes)
        indexes = indexes[filter_vec]
        rdist = np.apply_along_axis(rdist_fun, axis=1, arr=indexes)
        fvalue = np.sum(rdist)
        if fvalue < self.best_value:
            self.best_value = fvalue
            update_plot(x, fvalue, self.nb_call, self.best_value, better=True)
        else:
            update_plot(x, fvalue, self.nb_call, self.best_value, better=False)
        self.nb_call +=1 
        return fvalue


n_particles = 12
lw = np.array([0] * (n_particles * 2))
up = np.concatenate((
    np.repeat(np.pi, n_particles),
    np.repeat(2 * np.pi, n_particles)), axis=None)
bounds=list(zip(lw, up))


fig = plt.figure()
ax = fig.add_subplot(projection='3d')

u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:20j]
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)

def init_sphere():
    ax.plot_wireframe(x, y, z, color="grey", linewidth=0.2)
    ax.plot_surface(x, y, z, color="g", alpha=0.1)
    return fig,

def update_plot(x, f, nb_call, best_value, better):
    ax.view_init(elev=20, azim=nb_call % 360 )
    ax.set_title(f'Nb function call: {nb_call} Energy: {best_value:.6f}')
    if better:
        plt.cla()
        init_sphere()
        x_mat = np.array(x).reshape(len(x) // 2, 2, order='F')
        y_mat = np.apply_along_axis(polar_to_cartesian, axis=1, arr=x_mat)
        for i in range(n_particles):
            ax.scatter(y_mat[i, 0], y_mat[i, 1], y_mat[i, 2])
        seq_vec = np.arange(0, n_particles)
        indexes = np.array(np.meshgrid(seq_vec, seq_vec)).T.reshape(-1, 2)
        filter_vec = np.apply_along_axis(filter_indexes, axis=1, arr=indexes)
        indexes = indexes[filter_vec]
        for i in range(indexes.shape[0]):
            ax.plot(
                [
                    y_mat[indexes[i, 0], 0],
                    y_mat[indexes[i, 1], 0],
                ],
                [
                    y_mat[indexes[i, 0], 1],
                    y_mat[indexes[i, 1], 1],
                ],
                [
                    y_mat[indexes[i, 0], 2],
                    y_mat[indexes[i, 1], 2],
                ], linewidth=0.9,
            )

    fig.canvas.draw()
    fig.canvas.flush_events()

plt.ion()
init_sphere()
ax.view_init(elev=20, azim=(90))
thomson = Thomson()
res = dual_annealing(thomson.objective, bounds=bounds)
# Out:
# /var/folders/92/r64sg4tn5534nvv00jw3h_m80000gn/T/ipykernel_42927/216101968.py:31: RuntimeWarning: divide by zero encountered in double_scalars
#   1 / np.sqrt(np.sum(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 109
#     107 ax.view_init(elev=20, azim=(90))
#     108 thomson = Thomson()
# --> 109 res = dual_annealing(thomson.objective, bounds=bounds)
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_dual_annealing.py:714, in dual_annealing(func, bounds, args, maxiter, minimizer_kwargs, initial_temp, restart_temp_ratio, visit, accept, maxfun, seed, no_local_search, callback, x0, local_search_options)
#     712 # Possible local search at the end of the strategy chain
#     713 if not no_local_search:
# --> 714     val = strategy_chain.local_search()
#     715     if val is not None:
#     716         message.append(val)
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_dual_annealing.py:325, in StrategyChain.local_search(self)
#     318 def local_search(self):
#     319     # Decision making for performing a local search
#     320     # based on strategy chain results
#     321     # If energy has been improved or no improvement since too long,
#     322     # performing a local search with the best strategy chain location
#     323     if self.energy_state_improved:
#     324         # Global energy has improved, let's see if LS improves further
# --> 325         e, x = self.minimizer_wrapper.local_search(self.energy_state.xbest,
#     326                                                    self.energy_state.ebest)
#     327         if e < self.energy_state.ebest:
#     328             self.not_improved_idx = 0
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_dual_annealing.py:418, in LocalSearchWrapper.local_search(self, x, e)
#     415 def local_search(self, x, e):
#     416     # Run local search from the given x location where energy value is e
#     417     x_tmp = np.copy(x)
# --> 418     mres = self.minimizer(self.func_wrapper.fun, x, **self.kwargs)
#     419     if 'njev' in mres:
#     420         self.func_wrapper.ngev += mres.njev
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_minimize.py:699, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     696     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     697                              **options)
#     698 elif meth == 'l-bfgs-b':
# --> 699     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     700                            callback=callback, **options)
#     701 elif meth == 'tnc':
#     702     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     703                         **options)
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_lbfgsb_py.py:360, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     354 task_str = task.tobytes()
#     355 if task_str.startswith(b'FG'):
#     356     # The minimization routine wants f and g at the current x.
#     357     # Note that interruptions due to maxfun are postponed
#     358     # until the completion of the current minimization iteration.
#     359     # Overwrite f and g:
# --> 360     f, g = func_and_grad(x)
#     361 elif task_str.startswith(b'NEW_X'):
#     362     # new iteration
#     363     n_iterations += 1
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_differentiable_functions.py:286, in ScalarFunction.fun_and_grad(self, x)
#     284     self._update_x_impl(x)
#     285 self._update_fun()
# --> 286 self._update_grad()
#     287 return self.f, self.g
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/scipy-1.9.3-py3.10-macosx-11-x86_64.egg/scipy/optimize/_dual_annealing.py:382, in ObjectiveFunWrapper.fun(self, x)
#     380 def fun(self, x):
#     381     self.nfev += 1
# --> 382     return self.func(x, *self.args)
#
# Cell In [2], line 46, in Thomson.objective(self, x)
#      44     update_plot(x, fvalue, self.nb_call, self.best_value, better=True)
#      45 else:
# ---> 46     update_plot(x, fvalue, self.nb_call, self.best_value, better=False)
#      47 self.nb_call +=1
#      48 return fvalue
#
# Cell In [2], line 102, in update_plot(x, f, nb_call, best_value, better)
#      86     for i in range(indexes.shape[0]):
#      87         ax.plot(
#      88             [
#      89                 y_mat[indexes[i, 0], 0],
#    (...)
#      99             ], linewidth=0.9,
#     100         )
# --> 102 fig.canvas.draw()
#     103 fig.canvas.flush_events()
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/backends/backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/figure.py:3071, in Figure.draw(self, renderer)
#    3068         # ValueError can occur when resizing a window.
#    3070 self.patch.draw(renderer)
# -> 3071 mimage._draw_list_compositing_images(
#    3072     renderer, self, artists, self.suppressComposite)
#    3074 for sfig in self.subfigs:
#    3075     sfig.draw(renderer)
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/mpl_toolkits/mplot3d/axes3d.py:462, in Axes3D.draw(self, renderer)
#     459         axis.draw(renderer)
#     461 # Then rest
# --> 462 super().draw(renderer)
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/axes/_base.py:3107, in _AxesBase.draw(self, renderer)
#    3104         a.draw(renderer)
#    3105     renderer.stop_rasterizing()
# -> 3107 mimage._draw_list_compositing_images(
#    3108     renderer, self, artists, self.figure.suppressComposite)
#    3110 renderer.close_group('axes')
#    3111 self.stale = False
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/mpl_toolkits/mplot3d/art3d.py:218, in Line3D.draw(self, renderer)
#     216 xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, self.axes.M)
#     217 self.set_data(xs, ys)
# --> 218 super().draw(renderer)
#     219 self.stale = False
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/lines.py:758, in Line2D.draw(self, renderer)
#     755 renderer.open_group('line2d', self.get_gid())
#     756 if self._lineStyles[self._linestyle] != '_draw_nothing':
#     757     tpath, affine = (self._get_transformed_path()
# --> 758                      .get_transformed_path_and_affine())
#     759     if len(tpath.vertices):
#     760         gc = renderer.new_gc()
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/transforms.py:2786, in TransformedPath.get_transformed_path_and_affine(self)
#    2780 def get_transformed_path_and_affine(self):
#    2781     """
#    2782     Return a copy of the child path, with the non-affine part of
#    2783     the transform already applied, along with the affine part of
#    2784     the path necessary to complete the transformation.
#    2785     """
# -> 2786     self._revalidate()
#    2787     return self._transformed_path, self.get_affine()
#
# File ~/Software/python-virtualenvs/pyconie2022/lib/python3.10/site-packages/matplotlib-3.6.2-py3.10-macosx-11-x86_64.egg/matplotlib/transforms.py:2764, in TransformedPath._revalidate(self)
#    2759 if (self._invalid & self.INVALID_NON_AFFINE == self.INVALID_NON_AFFINE
#    2760         or self._transformed_path is None):
#    2761     self._transformed_path = \
#    2762         self._transform.transform_path_non_affine(self._path)
#    2763     self._transformed_points = \
# -> 2764         Path._fast_from_codes_and_verts(
#    2765             self._transform.transform_non_affine(self._path.vertices),
#    2766             None, self._path)
#    2767 self._invalid = 0
#
# KeyboardInterrupt:
